# %%
import pandas as pd

# %% [markdown]
# Load the data

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
train['Fare'].max()
# Out:
# np.float64(512.3292)

# %%
train['Fare'].min()
# Out:
# np.float64(0.0)

# %%
train['Fare'].value_counts()
# Out:
# Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 13.8583     1
# 50.4958     1
# 5.0000      1
# 9.8458      1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %%
def compute_percentile_ranges(column):
    #Define percentile ranges
    ranges = [(0, 50), (50, 100), (100, 200), (200, 300), (300, 400), (400, 500), (500, 600)]

    percentiles = {(low, high): (column.quantile(low/600), column.quantile(high/600)) for low, high in ranges}

    counts = {}

    for r, (low, high) in percentiles.items():
        counts[r] = ((column >= low) & (column < high)).sum()
    
    return counts


print(compute_percentile_ranges(train['Fare']))
# Out:
# {(0, 50): np.int64(70), (50, 100): np.int64(70), (100, 200): np.int64(155), (200, 300): np.int64(145), (300, 400): np.int64(125), (400, 500): np.int64(177), (500, 600): np.int64(146)}

# %%
fare_bin_column = pd.cut(train['Fare'], 8)

# %%
train.insert(10, 'Fare Bin', fare_bin_column)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare           Fare Bin Cabin Embarked
# 0      0         A/5 21171   7.2500   (-0.512, 64.041]   NaN        S
# 1      0          PC 17599  71.2833  (64.041, 128.082]   C85        C
# 2      0  STON/O2. 3101282   7.9250   (-0.512, 64.041]   NaN        S
# ...
